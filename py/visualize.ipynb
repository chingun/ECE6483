# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("1.csv",delimiter=";")
plt.plot(df1.x)
plt.plot(df1.y)
plt.plot(df1.z)

plt.show()

# %%
df2 = pd.read_csv("2.csv",delimiter=";")
plt.plot(df2.x)
plt.plot(df2.y)
plt.plot(df2.z)

plt.show()

# %%
df1 = pd.read_csv("1.csv",delimiter=";")
plt.plot(df1.x)
plt.plot(df1.y)
plt.plot(df1.z)

plt.show()

# %%
df2 = pd.read_csv("2.csv",delimiter=";")
plt.plot(df2.x)
plt.plot(df2.y)
plt.plot(df2.z)

plt.show()

# %%
pd.util.hash_pandas_object(df4)
# Out:
# 0      3401627839641170515
# 1     12838595623566329652
# 2      5615109324902315568
# 3      8545915456264789939
# 4     17413455988235307716
#               ...
# 95     3464138346237868123
# 96     9945265201443869586
# 97     3062124255459781400
# 98    18216190232401747438
# 99     6488810790580462510
# Length: 100, dtype: uint64

# %%
pd.util.hash_pandas_object(df3)
# Out:
# 0      3401627839641170515
# 1      7791297919900469762
# 2      8287175298101925875
# 3      7360525737122878588
# 4     12407266432816151143
#               ...
# 95      278020381892455829
# 96      368532042092849224
# 97     6926546789141386667
# 98      894809028618124669
# 99     4990192915496489109
# Length: 100, dtype: uint64

# %%
from pyLSHash import LSHash

# %%
lsh = LSHash(hash_size=10, input_dim=100)
